# %% [markdown]
# # Lesson 3: Finding "People You May Know"
#
# ## Overview
# A core feature of any social network is suggesting new friends. The classic approach is based on **second-degree connections** – friends of your friends who you don't already know.
#
# ### Algorithm
# 1. For every direct friend of the target user, iterate over *that friend's* friend list.
# 2. If a person is not the target user and not already a direct friend, they are a candidate.
# 3. Count how many mutual friends connect the candidate to the target user.
# 4. Sort candidates by mutual-friend count (highest first) to rank the suggestions.

# %%
import json

def load_data(filename):
    with open(filename, "r") as file:
        return json.load(file)

def find_people_you_may_know(user_id, data):
    user_friends = {}
    for user in data["users"]:
        user_friends[user["id"]] = set(user["friends"])
    
    if user_id not in user_friends:
        return []
    
    direct_friends = user_friends[user_id]
    suggestions = {}
    
    for friend in direct_friends:
        # For all friends of friend
        for mutual in user_friends[friend]:
            # If mutual id is not the same user and not already a direct friend of user
            if mutual != user_id and mutual not in direct_friends:
                # Count mutual friends
                suggestions[mutual] = suggestions.get(mutual, 0) + 1
    
    sorted_suggestions = sorted(suggestions.items(), key=lambda x: x[1], reverse=True)
    return [user_id for user_id, _ in sorted_suggestions]

# Load data
data = load_data("data.json")
user_id = 1  # Example: Finding suggestions for Amit
recommendations = find_people_you_may_know(user_id, data)
print(f"People You May Know for User {user_id}: {recommendations}")
# Out:
# People You May Know for User 1: [4]

# %% [markdown]
# ## Try Other Users
# Let's generate suggestions for every user in the dataset to see the algorithm in action.

# %%
# Generate 'People You May Know' suggestions for all users
print('=== People You May Know (all users) ===\n')
for user in data['users']:
    uid = user['id']
    suggestions = find_people_you_may_know(uid, data)
    # Map IDs back to names
    id_to_name = {u['id']: u['name'] for u in data['users']}
    names = [id_to_name[s] for s in suggestions if s in id_to_name]
    print(f"{user['name']} (ID {uid}) → Suggestions: {names if names else 'None'}")
# Out:
# === People You May Know (all users) ===
#
# Amit (ID 1) → Suggestions: ['Sara']
# Priya (ID 2) → Suggestions: ['Rahul']
# Rahul (ID 3) → Suggestions: ['Priya']
# Sara (ID 4) → Suggestions: ['Amit']
